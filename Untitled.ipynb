# %%
#!/usr/bin/env python
# coding: utf-8

# In[124]:


import requests
import json
from bs4 import BeautifulSoup
from urllib.request import urlopen


# In[131]:


allJobs = [] # list of dictionary for all jobs

# skills and categories
skills = ['python', 'java', 'c++', 'sql', 'manage', 'javascript', 
          'linux', 'team', 'problem solving', 'front end', 'back end', 
          'html', 'css','json', 'xml','api', 'linux', 'nodejs', 'c#', 
          'spark', 'sas', 'matlab', 'excel', 'spark', 'hadoop', 'azure', 
          'spss', 'git', 'aws']

aiKeys = ['ai', 'a.i.', 'artificial intelligence', 'artificial']

dlKeys= ['deep learning', 'neural networks', 'big data', 'deep', 'statistics']

mlKeys = ['data mining', 'machine learning', 'cnn', 'rbm', 
          'machine', 'natural language', 'regression', 'fault diagnosis', 'intrusion detection']

seKeys = ['software engineer', 'software development','code']

keyWordEdu = ['masters', 'bachelors', "master's", "bachelor's", 'phd', 'undergrad', 'graduate', 'undergraduate', 'ged', "graduate's", "undergraduate's", "associate's", 'doctoral']

# In[132]:


def getSomeDict(job, location, maxPages):
    baseLink = 'https://www.indeed.com/'
    webAddr = baseLink + 'jobs?q=' + job.replace (' ', '+')
    webAddr = webAddr + ('' if location == '' else '&l=' + location) + '&start=0'
    
    for x in range(0, maxPages):
        link=webAddr.replace(webAddr[-1], str(x))
        #print(link)
        getDict(link)


# In[133]:


def getDict(url):
    dicList = []
    coList = []
    titList = []
    locList = []
    dateList =[]
    payList = []
    linkList = []
    skillList = []
    descList = []
    catList = []
    eduList = []
    
    source = requests.get(url).text
    soup = BeautifulSoup(source, 'lxml')

    #titles and links
    for pos in soup.find_all('div', class_='title'):
        titList.append(pos.a.get('title'))
        link = pos.a.get('href')
        linkList.append("https://www.indeed.com" + link)

    # company
    # 'result-link-source' may not be needed? 
    for span in soup.find_all(name='span', class_=['company', 'result-link-source']):
        coList.append(span.text.strip())
    
    
    # pay
    for div in soup.find_all(name='div', attrs={'class':'row'}):
        try:
            payList.append(div.find(name='span', class_=['salaryText', 'sjcl']).text.replace('\n', ''))
        except:
            payList.append('N/A')
        
        
    #locations
    spans = soup.findAll(['div', 'span'], attrs={'class': 'location'})
    for span in spans:
        locList.append(span.text)


    #dates
    spans = soup.findAll('span', attrs={'class': 'date'})
    for span in spans:
        dateList.append(span.text)
        

    #go into job links
    for l in linkList:

        #description
        newSRC = requests.get(l).text
        newSoup = BeautifulSoup(newSRC, 'lxml')
        desc = newSoup.find('div', class_='jobsearch-jobDescriptionText')
        desc = desc.text
        descList.append(desc)
    
        foundSkills = []
        desc = desc.lower()
        for x in skills:
            if x in desc and x not in foundSkills:
                foundSkills.append(x)
        skillList.append(foundSkills)
        
        # primitive text classification
        # sums up occurunces of keywords and then appends the category tag associated with the highest count
        aiCNT = 0
        dlCNT = 0
        mlCNT = 0
        seCNT = 0
        otherCNT = 0
        for x in desc.split():
            if x in aiKeys:
                aiCNT += 1
                continue
            elif x in dlKeys:
                dlCNT += 1
                continue
            elif x in mlKeys:
                mlCNT += 1
                continue
            elif x in seKeys:
                seCNT += 1
                continue
            # need to improve other because it might always be listed as other
            #otherCNT += 1 # if no other count was incremented increment other

        mx = max(aiCNT, dlCNT, mlCNT, seCNT, otherCNT)
        if aiCNT == mx:
            catList.append('Artificial Intelligence')
        elif dlCNT == mx:
            catList.append('Deep Learning')
        elif mlCNT == mx:
            catList.append('Machine Learning')
        elif seCNT == mx:
            catList.append('Software Engineer')
        elif otherCNT == mx: # consider difference of counts?
            catList.append('Other')


        #Education
        foundEdu = []
        desc = desc.lower()
        for x in desc.split():
            if x in keyWordEdu:
                foundEdu.append(x)
        eduList.append(foundEdu)
    
    for i in range (0, len(titList)):
        allJobs.append(dict({'Company':coList[i], 'Location': locList[i], 
                             'Title': titList[i], 'Date Created': dateList[i], 
                             'Salary': payList[i], 'Link':linkList[i],'Skills': skillList[i], 
                             'Description': descList[i], 'Category': catList[i], 'Education': eduList[i]}))


# In[136]:


getSomeDict('data scientist', 'Chicago', 6)


# In[ ]:

# %%
allJobs
# Out:
# [{'Company': 'Seen by Indeed',
#   'Location': 'Chicago, IL',
#   'Title': 'Data Scientist',
#   'Date Created': '30+ days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0DhVAxkc_TxySVbUOs6bxWYWOfhmDTNcVTjFFBAY1FXZz6G2ZVf9e4MK_H5xrDYyl4Wvt9iFPr0dwa-PGvIKeS_IBkZz1se8As_eo66dNcugE6QB4UvD86R0MhzhKq3oLIRLX_ocYh_12yx867ld9Zq8jzKz4_4OMNRW1RF6ntCv9cKrBm7Ko60CR_a5AClcdF-piGIZF1i12uKsbN8J15hUkHLmLU2yLm-neT3doEy9wh1MYIyngDl8FjQk0jZ7IdzgOAqWdK77UXtKxm87TEphKrcpSV4174aelvDrRd_0hMV_0M9iyFcR54soF-va32iCC-xHsnIrL5Ow7gyc_IvEbwUiz_D_XWwaU-N8eb_yNIQPeD4EyFuvePwvnPE3Wwz7BqxM5GIVkfMZ1yEzHPnL0dMCzpn83UV1PLjPo6XWB0O5YiqOnx-kJLIm9Wzxzfa-ibzJSVErbHdjTZyG42f1E9W6AMxf_YtleeUQovPx535mmMFrUewxq2hspz_XaP1FZrb36II56VWqE6ljXpWxuqbfDngkzYpH6h1mkm7Y5GywBx9ZpATowAMtjc985mG9KLQ44S2b2oTJb13qvhW4Zb7qY0pK4Y=&p=0&fvj=1&vjs=3',
#   'Skills': [],
#   'Description': "With one application you can be considered for thousands of tech roles from leading companies on Seen.\n\nSeen by Indeed is a free service that connects you to opportunities that take you further in your career.\nJoin today to be seen and make your mark in your next tech role.\nWith just one application, we'll show you off to hundreds of employers once your profile is approved.\nSeen matches you to opportunities based off where you've been and where you want to go in your career.\nTalk to career coaches for free to help you set your best foot forward whether it be during the interview process or during a promotion.\nBy creating an account, you agree to Indeed's Terms of Service, Cookie Policy and Privacy Policy.",
#   'Category': 'Artificial Intelligence',
#   'Education': []},
#  {'Company': 'The Joint Commission',
#   'Location': 'Oakbrook Terrace, IL 60181',
#   'Title': 'Software Architect/Machine Learning',
#   'Date Created': 'Today',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0BRLSpPY_7Rjd0AZQSjtToxHMzmiG3CxkvtHID_pFg2NqKS3fEdN1eZYJRe3MF_ro_gcZYVHCZkya-rAmBf5d2Dj1ubv8PV2gemJGh61DLawFRkUL2ljOGGYF_NROdeIQky09USSitvHPINtMpW4jmasG0qE1NVIXpcwwvNTNqE8jx9zhZZfmebmxQhUrVo0mnPw1z_HbqhQJDVu8GLQ0tFq_iBvJpnFjcpNK7CEMgF50_rMmvdl1VTg3K89PS2ab9mmcqAbv1jQjh8FmEbn6gJVBRfJsFf_x68geMnSLTPTObYW7dw3k1rHJU6A8ZruHuJQVtPO2dLkRadke_BQL8LHLU8A3HsFPhFkmGpZs2inYhQziFPmPb7yRtQlupsK9eQ-sxrnpfSXDpLp2SLBH57ekXA9R0Y54Z8_-CjH327sCz4gC0JcTxyOL_Iv3WQ0VkyWw6QV2ZyAc7_8TrD8mDZMwhSOdIblnSnFVxHgOSYNWLzYWfngqxYBPAfKDI8i7lGARkabrGfl-yjnvrmFgzzFCRD9bcMgG3o5DLbORES9TKUxcmbBbhQZHTrLF3rYYuE4BRzadALRmguIy2cEkuqz7_U8VBqJVQ-IdSSYm8FUm7bQfohfITlmEhfk4d16wI7BoIZfx9OeAHFRuA-dIvXVZ9aHU9k8DGeagk-Dtg3Qo0JDfTj9Od6xUdUAiAh7oxeYiSnO3aAzA-sEub5_PO5RnadTrYCMp_68PS1iBWdkJYNhxU6vOwzTf7XG7MUh7zJTcbm9g-3MXwSNytU6VAvzdmc8ubjhE38x0O-C5idSOqJE_oP3zAdAxlIDEfyqXk=&p=1&fvj=0&vjs=3',
#   'Skills': ['python',
#    'sql',
#    'manage',
#    'team',
#    'problem solving',
#    'xml',
#    'api',
#    'c#',
#    'excel',
#    'hadoop',
#    'azure',
#    'aws'],
#   'Description': "Overview:\nGENERAL SUMMARY:\nKey Leader of IT department that is responsible for coordination of all activities of the project team. This individual is responsible for feasibility studies, time and cost estimates, budgets, and the establishment and implementation of new or revised application systems strategies. Works with the IT Leadership and Managers to assign personnel to various projects and directs their activities as a part of introducing new technologies and procedures. This individual confers with and advises IT management, matrix subordinates, and other technical staff on best practices for new and transitioning technologies. Prepares project activity and progress reports regarding the transition of the application systems and makes frequent presentations to senior management.\nResponsibilities:\nPRINCIPLE DUTIES AND RESPONSIBILITIES:\n\nDemonstrates elite understanding of contemporary technical environment and emerging technologies that can add high valued capabilities to business solutions. Responsible for partnering with IT management, other architects and software engineering teams to foster innovation, deliver high quality software and simplify technical environment.\nExcels in the IT full project SDLC. Responsible for initial phases of introducing new technology including requirements, analysis & technical design. Defines the method & approach for the introduction of new technology and integration into current systems.\nPerforms project leadership activities in support of introducing new technology, integration of multiple applications, or design of new development standards. Ensures the project team's end results fulfill the business needs.\nWorks with IT management to provide new technology estimates for introducing and integrating with the existing systems. Uses technical and business expertise to provide leadership and mentoring to all staff. Supports project resources in a functional, technical and environmental capacity during the project lifecycle. Provides performance review input for those analysts they oversee in a matrix capacity.\nLeads and directs the identification and resolution of issues related to test environment design, application construction, and configuration management. Ensures all deadlines and commitments are met. Works with infrastructure team for issue resolution. Ensures all deadlines and commitments are met.\nEstablishes policies and procedures as well as standards by documenting, communicating and training for IT development teams. Open to team member ideas and approaches along with mentoring/guiding them in the right direction. Works with, coordinates, and manages external resources and vendor selection as necessary.\nExhibits a complete understanding of full TJC business processes and IT systems along with recommending technology improvements that best fit our business. Provides technical guidance to other IT staff and user departments in developing standards, documentation and guidelines for new technology. Participates in health care, IT and other professional networks to ensure awareness of industry standards, trends and best practices in order to strengthen organizational and technical knowledge.\nTreat team members fairly and builds relationships within and across departments.\nQualifications:\nKNOWLEDGE, SKILLS AND ABILITIES REQUIRED:\n\nBachelor’s degree in Computer Science or other related field OR equivalent work experience. Master’s Degree (MIS or MBA) recommended.\nAt least 10 + years of technical / software product development work experience in a distributed multi-tier environment.\n7+ years of software development experience with a wide variety of applications is\nRequired\nExtensive data modeling and data architecture skills\nProgramming experience in C# and (Python, or R)\nBackground in machine learning frameworks such as TensorFlow or Keras\nKnowledge of Hadoop, Azure cognitive services, Azure NoSQL DB (like - Table Storage, Cosmos DB, Document ...
#   'Category': 'Machine Learning',
#   'Education': []},
#  {'Company': 'Kelly Services',
#   'Location': 'Chicago, IL 60601 (Loop area)',
#   'Title': 'Sr. Data Analyst - Chicago, IL',
#   'Date Created': '2 days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0D6qFSVCaa8tXn-rJ3OcXif2lPyFmwsE2iZBGE4YLg1gz3DzxANTQL26tb-SQ4b-KBeYRKv_hW9xLu5S-i7cGvjjxIAec1IHXro8Kv26QGAQAsGaKqjaZOy-9dsu8keIKABJ75jAlPxp2JOJQcl7ZsX8DBs8M2gIDQtR7XkphCecUT1VfYK1U8EEbGaYukvvSD8bnwgIvrf7y3HZMkw3KdHzOWFt3N2HiQ__kOcfxanBWR0FBnmfLUO2dZ5pbEbSFa6q_Diiqdjln54u243XeJYcbq4bhSwBkJ8pG_Ah4vTdyoZYJxFg4URfon_DogE-ED1a-yPFyHPCjX8j_4rAofoMoZ5OZIMQZPLECz1Rk-EZ0OYm9b8ISt3KO0kpLa2Gk3DYmiCKAy0cK7H4DaCSQlslcnC0w94h7NOf-iEv9vIINXvBNtiRY-F9EAPIVKGQhuk_J30Ypzt876s9_pU3psO2VWS3ZQncsVBpRWRT2QKNqO_ygURP5-hR2fB_V6AYkX9LA311s5wMuhccAcS36EgIOThJMCbggnCWbsmKn1RoSvgr2mxICt2rvHGfGq4USPtjT3_r8hxblk7C5POi2UUq-f2FFeXPAVtRnhAnkV2d_9tcku5dj1ed3X02eGErzw7VqKLXFtGCtpy369OSqqQt6SQ6kVNFIxggmz5TTOXewRm1O0f15IF07-vqaPCDlnc9nMBnhdKE7d4hWKkB6uoAwfqi-EGnRxZA9mEryfm33TiUX2vZIHGH8p4S70oOLpuQEJHU8YfvzaG6BI4jaI0C3AmIRo_gu3FQ_CloyOVJ2lfLzLJYfLiJejki8peiLc1EL1UfT2Auo5EH_q_pBl5CUPc4I-FLb8UpeqkgCy6vgX0aC_sIMgqpaLb9-FaQRl-wycr-Qw8Mz9rzwl2p5OJ8gsm5StmfMZjYBn_ruMlLyzNB1dm8GzN31chB_-2oXl4sji_1o2jo1kWiZZOIfE33jhfxpjZT2EW54YfYVV-OcTHnb5CDLRVVKqLxVtnjG9FYz9ljZTQVJcft8ikN8qAPJ7GJLilSQWA1w3OR75ERQ==&p=2&fvj=0&vjs=3',
#   'Skills': ['manage', 'team'],
#   'Description': 'Kelly Services is seeking a Sr. Data Analyst for a leading hospital and health care company.\nJob Title: Sr. Data Analyst\nLocation: Chicago, IL\nType: Contract (W2)\nLength: 1 months (Possibility of extension)\nPay Rate: $35/HR\nDescription: This position is responsible for developing requirements related to data and reporting for the Data and Analytics team – focusing on clinical data (Lab, ADT, CCDA, Biometrics, etc). Identifies key healthcare, innovation and technology trends and analyzes the potential implications for the curation of data products valuable to the business. Participates in planning discussions and other business unit discussions to understand and capture high level business needs. Responsible for the development of epics/features, high level user stories and user acceptance criteria to drive planning for the data analytics component of projects and programs. Leads the gathering, analysis, documentation, and communication of business and technical requirements for new solutions or enhancements for current solutions. Validates business and technical requirements are met during the project delivery process and during User Acceptance Testing.\n\nJOB REQUIREMENTS:\nBachelor’s Degree in computer science, data information systems, health information management field OR 4 years’ experience in data analysis, reporting and/or product management4 years’ experience in data analysis and/or preparing database reports2 years’ experience gathering requirements and writing user stories/acceptance criteriaStrong interpersonal skills and ability to project manage and work with cross-functional teamsAnalytical skills, Organizational and Planning skillsVerbal and written communications skills to interact with internal customers, leadership and vendorsExperience analyzing and preparing recommendations on process improvementExperience with Agile Management and product lifecycleExperience with JIRA\n\nPREFERRED JOB REQUIREMENTS:\nExperience with healthcare clinical data i.e. Lab, CCDA, ADT, EMR, Biometrics, etc.Knowledge of HL7 and HEDIS quality reporting\n*** If this position may be of interest to you, please email me back at shai879@kellyservices.com (with your most up to date resume, for further consideration) and advise the best time and number at which you can be reached. If not for yourself, feel free to share this opportunity within your network! ***\n\nShazneen Irani\nProfessional Technical Recruiter\nKelly Services, Inc.\nshai879@kellyservices.com\nkellyservices.com\n\n\nWhy Kelly®?\n\nAs a worker today, it’s up to you to take charge of your career and look for opportunities to learn, grow, and achieve your potential. Helping you find what’s next is what we’re all about. We know what’s going on in the evolving world of work—just ask the nearly 500,000 people we employ each year. Connecting with us means getting the support, guidance, and opportunities needed to take your career where you may have never imagined.\nAbout Kelly®\nAt Kelly, we’re always thinking about what’s next and advising job seekers on new ways of working to reach their full potential. In fact, we’re a leading advocate for temporary/nontraditional workstyles, because we believe they allow flexibility and tremendous growth opportunities that enable a better way to work and live. Connecting great people with great companies is what we do best, and our employment opportunities span a wide variety of workstyles, skill levels, and industries around the world.\nKelly is an equal opportunity employer committed to employing a diverse workforce, including, but not limited to, minorities, females, individuals with disabilities, protected veterans, sexual orientation, gender identity. Equal Employment Opportunity is The Law.\n#KellyGTS',
#   'Category': 'Artificial Intelligence',
#   'Education': []},
#  {'Company': 'Hitachi Solutions',
#   'Location': 'Chicago, IL',
#   'Title': 'Junior Data Scientist',
#   'Date Created': '29 days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/rc/clk?jk=293b0e11a02a0456&fccid=28f79c18789111e8&vjs=3',
#   'Skills': ['manage', 'team', 'azure'],
#   'Description': "Company Description\n\nHitachi Solutions is a core IT Company of the Hitachi Group, which employs over 330,000 people worldwide. Headquartered in Tokyo, Japan, Hitachi Solutions' reach extends to group companies in Japan and abroad, working with a worldwide network of alliance partners. Through systems integration, we strive to provide ideal solutions and products to customers in a diverse set of countries and regions including Asia, North America and Europe. Using a portfolio of management consulting, implementation, and support services, we help our clients compete with the largest global enterprises leveraging powerful, affordable, and easy to use industry solutions built on Microsoft technologies. Our vision is to help you achieve your vision through superior products, prices, and people.\n\nJob Description\n\nAre you looking to work at the forefront of artificial intelligence and machine learning? We have a significant data analytics and management presence across many industries. With that footprint comes massive amounts of data that can inform us about markets and ways to improve our client business practices.\nThis position will be part of the Data Science and Machine Learning team and will bring strong quantitative skills to our data science capabilities. You work in a multidisciplinary team exploring, connecting and mining internal data sources and will develop data models using algorithms for pattern detection and forecasting. In this position you will be managing projects that use advanced analytics techniques, such as optimization, forecasting, machine learning, predictive analytics, and statistical analysis, to develop solutions that help deliver significant value to a variety of our partners and clients.\nYou will be exposed to a wide spectrum of high visibility projects ranging from sales effectiveness, competitive intelligence, fraud detection, time series forecasting, operational efficiency, sourcing and procurement, supply-chain optimization and financial analysis.\nWhy is this role important for our company’s work?\nQuite simply, our clients and engineers need you. You’ll provide a fresh perspective to our industry experts who have 10-20 years of experience. You’ll come with a hungry mindset that is collaborative and helpful.\nWith your perspective, we’ll transform existing practices to think differently about innovation, will optimize existing processes and systems in the organization, and will think high-level about business impact to the greater world.\nOnce you’re here…\nYou'll have full access to our reference architecture. Our services methodology is built on reusable technology components, patterns, and processes that have been refined and proven on thousands of production solutions. You’ll learn to develop complex data architectures, solve for real-time data needs of large businesses, and navigate the changing landscape of the Azure stack.\nYou will collaborate regularly with our experts, work across numerous industries, clients, and technologies. You will learn something new every day and begin adding value to our team almost immediately. We have our flagship Launch Program to get you up to speed as quickly as possible.\nYou will partner with clients across several key industries including Healthcare, Manufacturing and Industrial Products, Financial Services, Professional Services, Engineering and High Technology, Retail and more.\nResponsibilities:\n\nDevelop and code models by applying algorithms to large structured as well as unstructured data sets for our more complex projects. Develop visualization products to share analysis across a large group of business users.Design strategies and propose algorithms to analyze and leverage data from existing as well as new data sources.Continuously seek out industry best practices and develop skills to create new capabilities for data analytics at clients to improve business decisions.Network with business stakeholders to develop a pipeli ...
#   'Category': 'Machine Learning',
#   'Education': ["bachelor's", "master's"]},
#  {'Company': 'DialogTech',
#   'Location': 'Chicago, IL 60606 (The Loop area)',
#   'Title': 'Data Labeler - Data Science (Part-Time)',
#   'Date Created': '2 days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/rc/clk?jk=d6bb20a0d19813df&fccid=825d153aec833ca2&vjs=3',
#   'Skills': ['team', 'api', 'excel', 'git'],
#   'Description': "DialogTech provides the leading AI-driven conversation intelligence platform for marketers at businesses that value inbound phone calls. When consumers call, DialogTech turns those conversations into actionable insights businesses use to improve marketing ROI, increase sales conversions, and deliver more personalized customer experiences, both online and over the phone. Recognized as the leader and pioneer in call analytics since 2007, DialogTech is the trusted conversation intelligence platform for many of the world's most successful brands and agencies.\n\nDialogTech is a venture funded, growth stage, digital marketing technology company with over 4,000 customers and 200 employees. Since the beginning of 2014, DialogTech has experienced over 300% growth in its enterprise customer base and doubled its average customer size.\n\nAs a Data Scientist Labeler, you will assist our team in crafting labeled data for machine learning projects. You will be successful in this position if you possess the ability to self-pace and prioritize work.\n\nResponsibilities:\n\nTake weekly batches of data, and label it according to the project requirements with a sufficient level of accuracy\nYou will be responsible for the quality assurance of all data sets\nProvide support to the Data Science Team to design and execute experiments\nReview and report any trouble related to the figures\nUse audio-processing software to listen to calls, and produce summaries of the calls, assign labels to the whole call, as well as precisely mark individual words and phrases said on the calls\n\nThe must haves:\n\nSelf-motivated and assume ownership of a project\nAnalytical mindset, tech savvy and able to work in a dynamic environment\nAbility to learn audio-processing software and Microsoft Excel\nEmpathetic to learning new software and languages within Data Science\nReliable, committed and motivated\n\nThe nice to haves:\n\nA general understanding of Sales principles\nExperience and understanding of data review and analysis\nCall center or customer service experience is a plus\n\nWhat we offer:\n\nThe opportunity to work on a team that develops work class solutions with groundbreaking technology\nA great culture and environment. Free snacks and beverages, ping pong, foosball and a putting green to name a few.\n\nIn this role, you'll be participating in driving innovation within the company, working on rapid prototypes and research. You will find success if you will enjoy learning, pragmatic thinking, and critical reasoning.\n\nJoin us at one of the 101 Best and Brightest Places to Work in Chicago and nationally, 10 times running, Chicago Tribune's Top 100 Workplaces company and a 2017 Crain's Fast 50 company!\n\nWe are an equal opportunity employer and value diversity at our company. We do not discriminate on the basis of race, religion, color, national origin, gender, sexual orientation, age, marital status, veteran status, or disability status",
#   'Category': 'Machine Learning',
#   'Education': []},
#  {'Company': 'Relayr',
#   'Location': 'Chicago, IL 60638 (Garfield Ridge area)',
#   'Title': 'Data Scientist - IoT (Chicago)',
#   'Date Created': 'Today',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/rc/clk?jk=ff19e1a651125c6b&fccid=b2a647a4627655a5&vjs=3',
#   'Skills': ['python', 'java', 'c++', 'team', 'spark', 'git'],
#   'Description': 'Relayr is the Industrial Internet of Things (IIoT) powerhouse delivering the most complete solution for risk-free digital transformations. Our unique value stack combines pioneering IIoT technologies with skilled delivery, exclusive financing, and risk-free insurance models.\n\n\nWe unleash data insights from existing equipment, machines and production lines to improve our customers’ business outcomes. With around 300 employees, we are a truly global family with locations in Germany, the USA, Poland, Italy, France, and the UK. Named twice the hottest start-up in Berlin by WIRED magazine and a winner of The Spark - the German Digital Award, relayr is now part of the Munich Re group.\n\n\nOur analytics team pushes the boundaries of technology. We tackle challenging problems in the fields of data engineering, data science, and machine learning research to develop solutions from early prototypes to fully-fledged production-ready systems. We are looking to recruit highly motivated engineers and scientists that can successfully rise to the diverse challenges in the emerging market of Internet of Things. Currently we are seeking a Data Scientist to join our team and be based in our Chicago office.\n\n\nYour tasks:\n\n\nHelp Relayr build the world’s most advanced IoT Cloud Platform.\nDevelop and assist in developing internal data processing tools.\nDesign, prototype and refine machine learning algorithms.\nResearch new machine learning methods and publish papers.\nDesign, prototype and collaborate with the backend team in implementing large scale data processing systems for the cloud and edge.\nPerform ad-hoc data analysis and present results.\nPrototype and iterate quickly.\nEngage in architectural discussions.\nParticipate in customer workshops to map business goals to the set of products we are developing.\n\n\nYour skills:\n\n\nMinimum 3-5 years of experience in the analytics field\nSignificant experience with machine learning techniques, ideally supervised learning and anomaly detection\nSignificant experience with Deep Learning\nGood experience with Python and Java, C++ and Apache Spark are a bonus\nComfortable with database systems and distributed processing\nAbility to explain data science concepts and requirements to non-technical audiences\n\n\nWe Offer:\n\n\nA diverse and friendly team with people from all over the world – Germany, Poland, US, UK, France, Italy.\nConnecting you with a network of companies and people from around the globe.\nCompetitive salary and a learning environment where you can extend and build upon your skills and interests, a focus on growth.\nKnowledge sharing from the best entrepreneurs in the industry.\nEasy integration into a highly professional and passionate team.\nGood office location in central Chicago area\nWe offer the ability to work in a cutting-edge field with the best people in the IoT industry!\n\n\nSound interesting? Please apply here:\n\nhttps://relayr.bamboohr.com/jobs/view.php?id=136',
#   'Category': 'Machine Learning',
#   'Education': []},
#  {'Company': 'Capax Global LLC',
#   'Location': 'Chicago, IL',
#   'Title': 'Data Scientist',
#   'Date Created': '30+ days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/rc/clk?jk=85171a0feb34c38a&fccid=4764948a627d0c5d&vjs=3',
#   'Skills': ['python', 'manage', 'team', 'spark', 'excel', 'hadoop', 'git'],
#   'Description': 'Do you want to work at the forefront of artificial intelligence and machine learning? CapaxGlobal has a significant data analytics and management presence across many industries. With that footprint comes massive amounts of data that can inform us about markets and ways to improve our client business practices. This position will be part of the Data Science and Machine Learning team and will bring strong quantitative skills to our data science capabilities. You work in a multidisciplinary team exploring, connecting and mining internal data sources and will develop data models using algorithms for pattern detection and forecasting. In this position you will be managing projects that use advanced analytics techniques, such as optimization, forecasting, machine learning, predictive analytics, and statistical analysis, to develop solutions that help deliver significant value to a variety of Capax’s partners and clients. Candidates will be exposed to a wide spectrum of high visibility projects ranging from sales effectiveness, competitive intelligence, fraud detection, time series forecasting, operational efficiency, sourcing and procurement, supply-chain optimization and financial analysis.\nLocation: Chicago IL | Philadelphia PA | Remote\nTravel: Up to 30%\nResponsibilities\nDevelop and code models by applying algorithms to large structured as well as unstructured data sets for our more complex projects. Develop visualization products to share analysis across a large group of business users.\nDesign strategies and propose algorithms to analyze and leverage data from existing as well as new data sources.\nContinuously seek out industry best practices and develop skills to create new capabilities for data analytics at clients to improve business decisions.\nNetwork with business stakeholders to develop a pipeline of data science projects aligned with business strategies. Translate complex and ambiguous business problems into project charters clearly identifying technical risks and project scope.\nParticipate on cross-disciplinary project team of database specialists, data scientists, and business subject-matter experts to complete project deliverables.\nQualifications\nBachelor’s degree from an accredited college/university in Computer Science, Computational Linguistics, Statistics, Mathematics, Engineering, Bioinformatics, Physics, Operations Research or related fields.\nMaster’s degree in data science, applied mathematics, or bioinformatics preferred.\nMinimum 6 years relevant work experience (if Bachelor’s degree) or minimum 3 years relevant work experience (if Master’s degree) with a proven track record in driving value in a commercial setting using data science skills.\nIn-depth knowledge of various modeling algorithms e.g. Linear, GLMs, trees based models, neural networks, clustering, PCA, and time series models.\nProficiency in R (e.g. ggplot2, cluster, dplyr, caret), Python (e.g. pandas, scikit-learn, bokeh, nltk), Spark – MLlib, H20, or other statistical tools.\nMinimum 2 years experience working in a data science or machine learning environment.\nIn-depth knowledge of databases, data modeling, Hadoop, and distributed computing frameworks.\nExperience in software development environment, Agile, and code management/versioning (e.g. git).\nStrong EDA skills and experience/knowledge.\nAbility to understand complex and ambiguous business needs and applying the right tools and approaches.\nCollaborative team player.\nExcellent communication skills, both written and verbal.\nExperience developing and testing machine learning and/or statistical projects.\nStrong presentation skills. Ability to present statistical results to lay persons in an easy to understand way.\nWe are looking for all levels of data science experience, jr through sr.',
#   'Category': 'Machine Learning',
#   'Education': []},
#  {'Company': 'Stryker',
#   'Location': 'Chicago, IL',
#   'Title': 'Data Scientist',
#   'Date Created': '30+ days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/rc/clk?jk=4e67204de20be56d&fccid=7847eeddd5ec77ae&vjs=3',
#   'Skills': ['python',
#    'sql',
#    'manage',
#    'team',
#    'problem solving',
#    'spark',
#    'excel',
#    'hadoop',
#    'azure',
#    'git',
#    'aws'],
#   'Description': 'T his position will grow Stryker’s capabilities in data analytics and management. The Data Scientist will be responsible for discovering information hidden in vast amounts of data to derive value for medical products and services, improve decision making, and build predictive algorithms to enhance outcomes and economic value. This position will be part of the SPS Data Analytics team and will bring strong quantitative skills to our data science capabilities. In this position you will be engaged on projects that use advanced analytics techniques, such as optimization, forecasting, machine learning, predictive maintenance, and statistical analysis to develop solutions that help deliver significant value to customers.\nResponsibilities\nWork with clinical, image, device, wearable, and demographic data to perform a variety of data mining and data analysis, using a variety of data tools, building predictive models as well as creating algorithms and simulations.\nDesign strategies and propose algorithms to analyze and leverage data from existing as well as new data sources to compare robotic and manual procedure outcomes\nEvaluate and manage third party vendors contracted to support data science related initiatives when applicable\nWork with various stakeholders throughout the organization as well as various customers to understand their needs and support them in applying various kinds of advanced analytics methods, such as predictive modeling or machine learning, to extract and visualize relevant information for solving problems in medical technologies\nContinuously seek out industry best practices and develop skills to create new capabilities for data analytics to improve business decisions and outcomes\nParticipate on cross-disciplinary project team of database engineers, data scientists, and business subject-matter experts to complete project deliverables\nIdentify and support business needs and recommend holistic solutions that integrate with existing data and technical solutions\nEffectively communicate and present complex analytics to stakeholders and customers\nDevelop and code models by applying algorithms to large structured as well as unstructured data sets for complex projects\nDevelop visualization products to share analysis across a large group of business users\nImplement models and visualizations into production data pipelines and analytics solutions that can be designed for production implementation in addition to research initiatives\nIdentify and act upon opportunities to improve the system process flow, performance and technical efficiencies\nQualifications/Experience\nBachelor’s degree in Computer Science, Computational Linguistics, Statistics, Mathematics, Engineering, Bioinformatics, Physics, Operations Research or related fields. Preferred Master’s in Data Science, Applied Mathematics, or Bioinformatics.\nMinimum 2-5 years relevant work experience with 2+ years of experience working with cloud-based solutions in Azure, AWS, or similar\nAbility to analyze business situations and apply excellent organizational/communication skills and attention to detail in business case evaluation and requirements analysis\nIn-depth knowledge of various modeling algorithms e.g. Linear, GLMs, tree-based models, neural networks, clustering, PCA, and time series models.\nProficiency in statistical tools / languages such as R (e.g. ggplot2, cluster, dplyr, caret), Python (e.g. pandas, scikit-learn, bokeh, nltk), Spark – MLlib, H20, or other tools\nStrong data analysis and problem solving skills, including excellent SQL (T-SQL, PL/SQL, Spark SQL) skills\nExperience with Data Engineering and Data Architecture such as ETL/ETL pipelines, data movement and data quality with Big Data, relational and dimensional modeling, and unstructured data stores\nIn-depth knowledge of databases, data modeling, Hadoop, and distributed computing frameworks\nExperience in software development environments using Agile / SCRUM, and code  ...
#   'Category': 'Machine Learning',
#   'Education': []},
#  {'Company': 'Crowe',
#   'Location': 'Chicago, IL 60606 (The Loop area)',
#   'Title': 'Data Scientist',
#   'Date Created': '29 days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/rc/clk?jk=6553afe835c5bb9f&fccid=994b5c764776123e&vjs=3',
#   'Skills': ['python', 'manage', 'team', 'git'],
#   'Description': "Company Overview:\nYour Journey at Crowe Starts Here:\nAt Crowe, you have the opportunity to deliver innovative solutions to today’s complex business issues. Crowe’s accounting, consulting, and technology personnel are widely recognized for their in-depth expertise and understanding of sophisticated process frameworks and enabling technologies, along with their commitment to delivering measurable results that help clients build business value. Our focus on emerging technology solutions along with our commitment to internal career growth and exceptional client value has resulted in a firm that is routinely recognized as a “Best Place to Work.” We are 75 years strong and still growing. Come grow with us!\nPosition Summary:\nAbout Crowe Data Science\n\nEverything we do is about making the future of human work more purposeful. We do this by leveraging state-of-the-art machine learning, modern architectures, and industry experts, to create AI-powered software-as-a-service.\n\nOur world-class Data Science professionals give Crowe the ability to capture and harness the power of data. A combination of data scientists and machine learning engineers create and deploy AI functionality into software to solve complex problems. This type of group, rarely seen anywhere except large tech companies, focuses on building scalable AI products, not just one-time insights. You will learn and build on a wide range of technologies – distinguishing Crowe in the market and driving the firm’s technology and innovation strategy.\n\nThe future is powered by AI, come build it with us.\n\nAbout the Team\nWe believe machine learning is software. While we know our way around Jupyter notebooks and ggplot2, they are not the end of our machine learning pipelines. Our team uses modern frameworks and tools (git, Docker, Kubernetes) to engineer machine learning solutions.\nWe foster good science. You are given the time and resources you need to build your expertise in your project, and you will guide fellow data scientists and other Crowe staff through your work.\nWe want to make good scientists better. Data scientists have plenty of options on the job market. We want to be one of the best ones. We have a journal club that meets weekly, regular opportunities for team members to teach each other, support for conferences, and recurring reading groups. Moreover, our team offers generous PTO, a flexible work from home policy, and a strong commitment to work-life balance. Company-wide, Crowe routinely wins awards for our support of our staff, including our Fortune 100 Best Companies to Work for in 2019.\nAbout the Role\nWe work on medium-term machine learning projects (4-8 months) with a high degree of autonomy.\nWe are not external facing. We harness the subject matter expertise of other Crowe teams to build machine learning products.\nWe write and review code for training, testing, and deploying machine learning models.\nQualifications:\nProgramming experience. Your job will require you to code - we write Python and R, so experience in these languages is preferred.\nMachine learning experience. You enjoy machine learning. You've gone deeper than reading blog posts, ideally having several example machine learning projects you can speak to within industry, academia, or your free time.\nCapacity for autonomy. You won't have to hit the ground running on day one, but you will have to manage your time between research, model development, and model deployment.\nStrong communication skills. You can both dive deep in machine learning and explain concepts to a non-technical audience.\nPreferred Skills\nHackiness. You like to code and have interest in learning new technologies. Using git and Docker as regular parts of your workflow sounds exciting.\nCuriosity about machine learning. You want to stay fresh in machine learning. You aren't afraid to take a stab at deep learning papers before they become blog posts (even if you don't have experience in it quite yet ...
#   'Category': 'Machine Learning',
#   'Education': []},
#  {'Company': 'SMS Assist, LLC',
#   'Location': 'Chicago, IL 60611 (Streeterville area)',
#   'Title': 'Data Scientist',
#   'Date Created': '3 days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/rc/clk?jk=9c35b99d1133603a&fccid=def0345f99ba0884&vjs=3',
#   'Skills': ['python',
#    'sql',
#    'team',
#    'problem solving',
#    'spark',
#    'sas',
#    'hadoop'],
#   'Description': "Responsibilities\nUse machine learning to improve and automate processes in SMS proprietary tools\nApply data mining techniques to make recommendations based on data and communicates results through insightful visualizations, reports and presentations\nImprove the dataset (or data repository) quality by cleaning the company’s data and collecting information from new sources\nTranslate business analytics problems into technical approaches in diverse domains such as vendor recommendation, work scheduling and technician dispatch, etc.\nCollaborate with different teams to develop, refine, and scale procedures and workflows.\nFoster a positive team environment\nEnsure confidentiality of internal and external data\nPerform ad-hoc projects and other duties as assigned\n Professional Skills\nThese are the professional skills we would expect from an individual fully established in this role.\nVerbal Communication - Proficient\nWritten Communication - Proficient\nTeamwork - Proficient\nRelationships - Proficient\nNegotiation - Proficient\nOrganizational Awareness - Proficient\nLearning Agility - Proficient\nAnalysis - Proficient\nProblem Solving - Proficient\nProcess Orientation - Proficient\nPrioritization - Advanced\nRole Specific Skills\nStrong mathematical and statistical skills.\nProgramming Languages: SQL, Python\nUnderstanding of ETL tools and database architecture\nQualifications\n Minimum Qualifications\nBachelor's degree in Math, Physics, Statistics, Computer Science, or with equivalent professional experience.\nExperience using a machine learning framework e.g. scikit-learn, torch or similar\nExperience with a statistical software (e.g. R, SAS)\n0-2 years of experience as a data scientist, working closely within a business\n Other Relevant Qualifications\nPhD or M.S. in related fields.\nExperience with natural language processing.\nAdvanced knowledge of Data Warehousing and BI best practices\nExperience with big data tools such as Spark, Hadoop, etc.\nExperience with Tableau or Superset.\n\nPlease note, this job description is not designed to cover or contain a comprehensive listing of activities, duties or responsibilities that are required of the employee for this job. Duties, responsibilities and activities, and schedule may change at any time with or without notice.\nSMS Assist is an Equal Opportunity Employer (EOE) that welcomes and encourages all applicants to apply regardless of age, race, color, religion, sex, sexual orientation, gender identify and/or expression, national origin, disability, veteran status, marital or parental status, ancestry, citizenship status, pregnancy or other reasons prohibited by law.",
#   'Category': 'Machine Learning',
#   'Education': ["bachelor's", 'phd']},
#  {'Company': 'CNA Insurance',
#   'Location': 'Chicago, IL 60604 (The Loop area)',
#   'Title': 'Data Scientist',
#   'Date Created': '23 days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/rc/clk?jk=16dab68256c1b2ee&fccid=811f2cdeeb2808d9&vjs=3',
#   'Skills': ['python',
#    'sql',
#    'manage',
#    'linux',
#    'team',
#    'problem solving',
#    'spark',
#    'git'],
#   'Description': 'Data Scientist-FIN0001LS\nDescription\n\nDescription\nHeadquartered in the heart of downtown Chicago, CNA is a leading commercial and specialty insurer, offering a diverse range of insurance products including Workers Compensation, Property, General Liability, Professional Liability, Cyber Insurance, Surety, and Warranty. We are one of the world leaders in underwriting non-medical professionals, from lawyers and accountants to architects and management consultants.\n\nWhat CNA offers\nA collaborative data science team with diverse skills and experiences, combined with deep expertise in statistical modeling, machine learning, and applications to insuranceModern cloud computing environment that enables you to explore data, build and deploy sophisticated models that impact key areas such as underwriting, pricing, claims management and risk controlSponsorship of continued professional growth through support for attending technical conferences, meetings and symposia\n\nWhat we are looking for\nThe successful candidate will:Use statistical methodologies and machine learning techniques to build state-of-the-art predictive models for the pricing, underwriting, claims, operations and marketing for an exciting mix of business insurance productsTranslate business problems into innovative analytical solutions\n\nEssential Duties & Responsibilities\nBuilds predictive, prescriptive or descriptive models in collaboration with business partners in functional areas such as Underwriting, Pricing, Distribution, Claims, Risk Control and IT to help address business questionsDesigns, writes, and tests advanced computer programs to extract, visualize and analyze data, to build models and to support model deployment into productionInterprets the results of models in business terms and communicates the contents of the models to business decision-makersParticipates in crafting products and innovative solutions that will provide revolutionary changeParticipates in special projects requiring advanced quantitative expertise\n\nRequired Skills, Knowledge & AbilitiesExperience in merging, cleaning, and preparing data for analysis from multiple sourcesExperience in extracting meaningful information from data using visualization and by formulating and testing hypotheses.Proficiency with SQL and programming experience in R or PythonProficiency with classical Generalized Linear Models, statistical inference, and re-sampling methods.Proficiency in LinuxPractical experience with version control (git, SVN)Strong analytical, problem solving and critical thinking skillsAttention to detail and accuracy of work, ability to spot and correct issuesStrong interpersonal and communication skillsStrong writing skills, including writing coherent documentation and reportsDrive to continuously improve and learn new tools and methodsAbility to work collaboratively with colleagues with diverse perspectives and backgroundsStrong time management skillsCapable of operating with little supervision and thinking independently and innovatively\n\nPreferred Skills, Knowledge & AbilitiesPractical experience with distributed computing (e.g., Apache Spark)Experience developing packages in R or PythonExperience with natural language processingKnowledge of insuranceExperience in building machine learning models\n\nReporting Relationship\nAVP or above\n\nEducation & Experience\nAdvanced degree in a quantitative discipline, with relevant work experience preferred.\n\n\nJob Finance and Accounting\nPrimary LocationUnited States-Illinois-Chicago\nOrganization Technology Executive\n\nJob Posting Feb 4, 2020\nUnposting Date Ongoing',
#   'Category': 'Machine Learning',
#   'Education': []},
#  {'Company': 'NCC Group',
#   'Location': 'Chicago, IL 60603 (The Loop area)',
#   'Title': 'Data Scientist',
#   'Date Created': '23 days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/rc/clk?jk=b2f2ced0c238830d&fccid=ff8ede93f50d155c&vjs=3',
#   'Skills': ['python', 'manage', 'team', 'api', 'azure', 'aws'],
#   'Description': 'Our mission is to make the world safer and more secure. And our core strength is the expertise of our people. We are committed to developing the future generation of cyber scientists, analysts and professionals. And we are always keen to hear from talented and experienced people who wish to join us in our vision to be the leading cyber security advisor.\nAbout You\nYou are a person who enjoys designing and implementing machine learning architectures as much as you do doing the science. You would enjoy the opportunity to build out your vision for a data science and machine learning capability in a highly technical company. You relish the challenge of unlocking the latent value in data to enable teams and organisations to succeed. You are fascinated by cyber security (even if you are not yourself a practitioner).\nYou want to teach machines.\nYou have a strong foundation in statistics and probability, can code in either Python or R, and have used at least one open-source machine-learning library or API to perform analytics. You have confidently built research-grade software and are comfortable prototyping ideas in your programming language of choice, although we’d certainly be keen to meet anyone who has pushed machine learning code into a production environment. You are familiar with large-scale data processing-relevant aspects of Microsoft Azure, Amazon AWS and/or Google GCP, along with modern computing architectures.\nAt minimum, you have practical understanding and experience of linear models, decision trees and neural networks, possibly through industry or academia. You have used (or are interested in learning) tools/frameworks such as scikit-learn, Tensorflow, Keras, etc.\nYou may also have theoretical or practical understanding of any of natural language processing, graph theory, algorithm design, or a specific research area in data science or machine learning.\nAbout the Team\nThe team is new to NCC Group sitting within the Group CTO Office, and works closely with our Research Directors. To say it is small and perfectly formed is an understatement. You will be part of a two-person team dedicated to data science and machine learning, with one person in Europe and the other in North America. This team will work on highly impactful deliverables that will be visible across both the organization as a whole. While we ask applied, real-world questions, there will be opportunities to also publish and present your work.\nWhile this role allows for a high degree of creativity with the opportunity to strongly influence our analytics roadmap, you will be among many inspiring, collaborative, and passionate colleagues within NCC Group. With respect to applied analytics, there is already a wider community of data science professionals who would be peers at NCC Group, primarily supporting our Managed Detection & Response business located in the Netherlands.\nAbout the Role\nYou will work as part of a team across NCC Group to:\nIdentify and understand our available data.\nDesign and implement our group approach to machine learning, applied analytics, and data science\nWork with other departments to ensure governance, compliance and security of our data science activities.\nPerform data science tasks to supply insights across teams within NCC Group.\nUltimately, help define and deliver our future machine learning strategy.\nOther:\nSome travel to other offices may be required',
#   'Category': 'Machine Learning',
#   'Education': []},
#  {'Company': 'Strike Social',
#   'Location': 'Chicago, IL 60606 (The Loop area)',
#   'Title': 'Data Scientist (Entry Level)',
#   'Date Created': '30+ days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/rc/clk?jk=4c6140ad5a1baf4a&fccid=cf4976b1a250fb07&vjs=3',
#   'Skills': ['python', 'team', 'api'],
# ...
#   'Category': 'Machine Learning',
#   'Education': ['phd']},
#  {'Company': 'NTT DATA Services',
#   'Location': 'Westchester, IL',
#   'Title': 'Sr. Data Analyst (Azure ML)',
#   'Date Created': '23 days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CmuepsQMx_RAdYAln1jJ69d8WzuEFDEHVXewtFdGhuxrxwynIGzFEiOFAajgAPN5QEKVIgtC0ib-hl41zc75L1D8gKlHgBoxFgrQdm9wnDp9eCCfbD7f5Q85fO5Rqzv0SUpC5qysDQME_FfLkm7qVT7fCz91J8EEDghYLIlHWfnrafkSEP7krbmxlcUn1fdUhz8aXf4g7W0SxRoIOvCvBst9HhRI4yWym4vh_2kYBQb1te1jD09HTYMkHZld0-OxRnRzVtuxOmbdRp7rsXBgFUbSmv4_o_KRoIWq_dKbcePkaqeA5Em2wiaA5JA70b4TLjbmLzJukjndVxSpxp8WEKVdgYdKkgSnVkjWHqv1h1f_TjWBjaRHx3RR_c2MThv8Kk7waCsbLLZquDy2hGnhmXpEY2FhYS4BM1HK1zzEiffrj8Jo49wsEBUnjtw1RiyyqbO41iCfJDW7OmyF4Pi_GI6WEl_-a1KitVskFHpEviYbNerx3BGDxSyrhOlHe_2JvQYER_Els6iMw2J4EAepqiuooVh075TN_9ZArcQDCDRIxeoqiM3r1p_MERlbvVD7FRdjrtcajUJefxp-ZvmnGivX60Lz9Z2aZKiXzBxM3oaEWvEp5v-vRSlzRMDyvAgo64aifvJ358-A==&p=12&fvj=0&vjs=3',
#   'Skills': ['sql', 'team', 'problem solving', 'azure', 'git', 'aws'],
#   'Description': 'At NTT DATA Services, we know that with the right people on board, anything is possible. The quality, integrity, and commitment of our employees are key factors in our company’s growth, market presence and our ability to help our clients stay a step ahead of the competition. By hiring the best people and helping them grow both professionally and personally, we ensure a bright future for NTT DATA Services and for the people who work here.\n\nNTT DATA Services currently seeks a Sr. Data Analyst (Azure ML) to join our team in Westchester (Chicago), Illinois.\n\nSr. Data Analyst should be expert in Azure with experience working on ML/AI projects. Manufacturing industry experience is strongly desired. In addition, they need to be expert in:\nData Analytics/Reporting\nProficiency in data integration, ETL, data modeling and have the ability to gather design and specification requirements\nDetermine best ML/AI solution, extract data, analyze and interpret & format reporting\nSet up delivery of outputs to requestor which can include automation, scheduled runs, access to a repository, etc.\nProblem Solving\nThrough use of reports, process knowledge and analysis, proficient at detecting patterns or problems that could affect overall data integrity\nAbility to think through alternatives, coming to decision quickly and following through with execution to resolve issues at the source\nCommunication\nDemonstrated ability to effectively communicate both orally and in writing in order to fully comprehend requests\nDeliver the output on time and on spec.\nPartnering/Collaboration/Teamwork:\nWork closely with global teams/colleagues, clients, partners and leadership.\nData issues typically trace back to partner departments within the IT Function and this position is expected to reach out proactively to resolve.\nQualifications4+ years’ experience as a Data Analyst.3+ years’ experience with SQL & SQL Server Reporting Services (SSRS).2+ years’ experience with Power BI.2+ years’ experience with Azure ML/Analytics.1+ years’ experience in the manufacturing industry.\nThis position is only available to those interested in direct staff employment opportunities with NTT DATA, Inc. or its subsidiaries. Please note, 1099 or corp-2-corp contractors or the equivalent will NOT be considered. We offer a full comprehensive benefits package that starts from your first day of employment.\nAbout NTT DATA Services\n\nNTT DATA Services partners with clients to navigate and simplify the modern complexities of business and technology, delivering the insights, solutions and outcomes that matter most. We deliver tangible business results by combining deep industry expertise with applied innovations in digital, cloud and automation across a comprehensive portfolio of consulting, applications, infrastructure and business process services. NTT DATA Services, headquartered in Plano, Texas, is a division of NTT DATA Corporation, a top 10 global business and IT services provider with 118,000+ professionals in more than 50 countries, and NTT Group, a partner to 88 percent of the Fortune 100. Visit nttdataservices.com to learn more.\n\nNTT DATA, Inc. (the “Company”) is an equal opportunity employer and makes employment decisions on the basis of merit and business needs. The Company will consider all qualified applicants for employment without regard to race, color, religious creed, citizenship, national origin, ancestry, age, sex, sexual orientation, gender identity, genetic information, physical or mental disability, veteran or marital status, or any other class protected by law. To comply with applicable laws ensuring equal employment opportunities to qualified individuals with a disability, the Company will make reasonable accommodations for the known physical or mental limitations of an otherwise qualified individual with a disability who is an applicant or an employee unless undue hardship to the Company would result.\n\nINDAPPS',
#   'Category': 'Deep Learning',
#   'Education': []},
#  {'Company': 'Allstate',
#   'Location': 'Chicago, IL',
#   'Title': 'Data Scientist - Insurance Modeling',
#   'Date Created': '30+ days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0BLH0BMQoDn-yw6Urt952hBm1JLFZ7WpBxND2cMIOjOqdmupiC_ZwOjlpaauaQKSrpbApKCN4F9LjxWxeGhQUZYACI0spKut8REk_ZXcZ_SUe68xsCCQp8qp4yiNhT4EHmztAcXNY0CAi0Sv_roHPT4s4uMRkilsmNpw5TItkhlRVQXmAzTl7cdX46NQet86Qv2wgBkKspiJz1ph4iPVBODoIwM04isfz75e6PJQBBJzcqHpNB35FJwkg8r8c3JqaHQcF6J3lgvh8WHutXbgHjMBxDoI9wGvMz1enbaZKwYnr4llK4Vdya2B7iJjSK5oQw_HgzoaDi02MoDtaW94_zpm-TdjS8n0hP98eRZ67yTN9FuSUWWUX-2QUNwtiC5WnWKiZTqMgZ34cCFFHHByqnQlKuv87BwR0gQIWZFLKX70YYzAIWN6TdOUmihffNK_oaXPWKztatQyW-kS3Yf_-_FAiEQA1VIfH3Zgf5cB6dhnygq6rJyHYpmOzPgHKQTV00iH1vqWcf3lE61zkS4Wh3RU5Fld9no4lxCZh7xk3OgzJcLfge40OOSq6LoBzqFl_Qda1icYzeM8cJj65tKiaxDbAD01yxfS82EQjHHR7qaAvRdFAUdNU9kRG17c1Iv-dZnKVCRhHA7t-JJBu8SgQt0auYQ1oK_TQzDMihqXEQfwDYE6zBc50rrYp_5uzjU0_0lq9OFmbCwF_ydCL-k0BbTuT6zMPl93BemptmCdJXsl2GXKbS1HdU2FV_9JLDdU4LjlTEGtnBI_C3hjph4FdrrAG1P152cfKXebGl9ZC57r_o2vsKPW-xOcdUNfbhMO5kczusAET24-ojjdSwlyS0W6plD-2ZvdA4et8ln2bcNugK-kUX2WHk0SuCHr_Kzw150SXiz60kReTd4l6FeCuc30lT0jtGmLSjDTihK55iHbkCP8wKXkFboP1GrkLlHDF8sleknTrLG-hS9kYsJ4-Oao7dpLomYGOhms9Bdv1rl02SyX-CTQwms-1IRbdY9mgBuS2S0dbNafiv02bKWP40av94vZsjjfqni_gIIvt1TLoWSLCRuoICS69Y_A5vfSHebpugBx5TP_lN2ds5BEgJXMy3usAUv06ShB4gYFnhaHaR2EdnhYipna7zVrrPKtTaTpKp8Jb9ghhbfKoY5l51D&p=13&fvj=0&vjs=3',
#   'Skills': ['python', 'sql', 'manage', 'team', 'sas'],
#   'Description': 'Where good people build rewarding careers.\nThink that working in the insurance field can’t be exciting, rewarding and challenging? Think again. You’ll help us reinvent protection and retirement to improve customers’ lives. We’ll help you make an impact with our training and mentoring offerings. Here, you’ll have the opportunity to expand and apply your skills in ways you never thought possible. And you’ll have fun doing it. Join a company of individuals with hopes, plans and passions, all using and developing our talents for good, at work and in life. Job Description\n\nJob Family Summary\nAnalytics is responsible for aligning with and contributing to corporate growth and profitability objectives by providing expert guidance, influencing business strategies, executing flawlessly, and rigorously defending our work.\n\nJob Summary\nThis position will work on the Modeling & Major Initiatives team as a part of the broader Auto & Home Analytics department. The Modeling & Major Initiatives team develops and maintains models used in ratemaking, economic analysis and underwriting. They also develop best practices and support enhancements to processes supporting major initiatives and the adaptation of models/major initiatives to state specific implementations. Data Scientists will utilize various statistical modeling techniques to support the creation of models, will educate business partners on the use of these models and will participate in innovative work to continually improve rating plan sophistication (such as the incorporation of telematics data) and decision-making support.\n\nThe Auto & Home Analytics Department supports pricing of personal insurance lines of business utilizing accepted actuarial and statistical standards and methodologies. Data Scientists work closely with their Analytics Manager to support business goals. Support will be provided for those who seek the Certified Specialist in Predictive Analytics (CSPA) credential.\n\nRemote work opportunities may be available to qualified candidates at the manager\'s discretion.\nKey Responsibilities\nUses best practices and traditional statistical/modeling techniques to develop and maintain rating, economic and other models as necessary and in consideration of the business goals of the model Provide tools, educate and support state teams in the implementation of models and other decision-making support Follows appropriate analyses to be conducted for projects to make recommendations to achieve corporate goals With minimal direction plans, implements, manages, and/or contributes on projects that are up to moderate complexity and are small-to moderate scale using accepted project management standards Forecasts short-term and long-term deliverables with assistance Tracks own plan performance and project timeline and communicates and presents project status Ensures project controls are in place throughout the lifecycle of the project within own tasks Supports the development/ design of new plans, programs, processes, products up to moderate complexity Assists in the development of communication strategies and materials to support new plans, programs, processes, products; solicits input from stakeholders Participates in the evaluation of procedures and processes regularly and makes observations or suggests improvements Contributes to market share growth and profitability by recommending changes to products, pricing, risk management Understands standard market specific implications of business strategies Assures proper execution of regulatory/legislative practices for Product Management Understands and follows internal and external compliance requirements/standards Trains/coaches team members or peers and actively shares expertise with peers Job Qualifications\nBachelor’s degree – preferably in related field of study such as finance, math/applied math, statistics/applied statistics, economics Proven insurance business knowledge – for example, understands econo ...
#   'Category': 'Artificial Intelligence',
#   'Education': []},
#  {'Company': 'Seen by Indeed',
#   'Location': 'Chicago, IL',
#   'Title': 'Data Scientist',
#   'Date Created': '30+ days ago',
#   'Salary': 'N/A',
#   'Link': 'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0DhVAxkc_TxySVbUOs6bxWYWOfhmDTNcVTjFFBAY1FXZz6G2ZVf9e4MK_H5xrDYyl4Wvt9iFPr0dwa-PGvIKeS_IBkZz1se8As_eo66dNcugE6QB4UvD86R0MhzhKq3oLIRLX_ocYh_12yx867ld9Zq8jzKz4_4OMNRW1RF6ntCv9cKrBm7Ko60CR_a5AClcdFElURP_fzH7moShsT0PkDS3i5tPtJZVKWY18sxKbhAASJlCdbp6QVu-cDjW9SL5OyEHGKg-dtidCmeWg4f3Az8AWgPNlsqBni1ScpofSQWGJBn-yqPpi3AlzzUDdP7L0Y3luQmYZ8fMV0QQVUJCosJ3ySYYlZ8nmwUhzXenNugfmQRbUWm1xKIS68HlMR9rxCwO3ycNz4SEQj52fdvIUDOglqNM0-K2n-8vI5M0cXsPDu32hWINqqOPz_q-vG-u5vQbgboKel8PC3UUwnfEnlUO7jHyU7Tyxpl-mi9E4N5-ydyPXWoi02242IKTn8Y19PPjFxpqiyAMwmsD8PJ0PGQJU5Oo9-iLkJmPui4jAs-LoQSjUfCObFxC-3YpjJG3iR2cBh8LlCE5zNTTnxVAHW3rPUAHxG8bjY=&p=14&fvj=1&vjs=3',
#   'Skills': [],
#   'Description': "With one application you can be considered for thousands of tech roles from leading companies on Seen.\n\nSeen by Indeed is a free service that connects you to opportunities that take you further in your career.\nJoin today to be seen and make your mark in your next tech role.\nWith just one application, we'll show you off to hundreds of employers once your profile is approved.\nSeen matches you to opportunities based off where you've been and where you want to go in your career.\nTalk to career coaches for free to help you set your best foot forward whether it be during the interview process or during a promotion.\nBy creating an account, you agree to Indeed's Terms of Service, Cookie Policy and Privacy Policy.",
#   'Category': 'Artificial Intelligence',
#   'Education': []}]
